# %% [markdown]
# # Opis zbioru
# Zbiór danych został pobrany z witryny [kaggle](https://www.kaggle.com/datasets/johnsmith88/heart-disease-dataset?resource=download), zawiera informacje na temat pacjentów - 13 atrybutów opisujących stan zdrowia i parametry biologiczne oraz jeden tzw. "target value" określający czy dana osoba została dotknięta chorobą serca czy też nie. Kolejne atrybuty uwzględnione w zbiorze danych:
# - wiek [age],
# - płeć [sex],
# - typ bólu w klatce piersiowej [cp],
# - ciśnienie krwi [trestbps],
# - poziom cholesterolu [chol],
# - poziom cukru [fbs],
# - maksymalne tętno [thalach],
# - wyniki elektrokardiograficzne [restecg],
# - występowanie bólu w klatce wywołanego wysiłkiem fizycznym (dławica piersiowa) [exang],
# - obniżenie odcinka [ST](https://pl.wikipedia.org/wiki/Odcinek_ST) wywołane wysiłkiem fizycznym [oldpeak],
# - nachylenie szczytowego wysiłkowego odcinka ST [slope]
# - liczba głównych naczyń zabarwionych w wyniku fluoroskopii [thai],
# - występowanie choroby serca [target]. <br>
#
# Atrybuty sex, cp, fbs, exang, target - w rzeczywistości zmienne jakościowe-porządkowe, zostały w zbiorze danych zaprezentowane jako zmienne ilościowe-dyskretne - liczby binarne 0 i 1. Dane pochodzą z eksperymentu - 1025 obserwacji. <br>
#
#
# # Wczytanie danych i analiza eksploracyjna

# %%
import pandas as pd 
import numpy as np 

df = pd.read_csv('heart.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# ### Informacje o typach danych i sprawdzenie instnienia wartości pustych

# %%
df.info() 
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# ...

# %% [markdown]
# ### Poglądowa analiza korelacji między zmiennymi

# %%
import seaborn as sns
from matplotlib import pyplot as plt

plt.figure(figsize=(16,8))
sns.heatmap(df.corr(), square=True, cmap='RdYlGn', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Największa ujamna korelacja występuję między atrybutami slope oraz oldpeak, sugeruje to że wraz ze wzrostem wartości jednej z cech druga obniża swoją wartość. Można było zakładać istnienie pewnej korelacji między tymi atrybutami, ponieważ oba z nich odnoszą się do odcinka ST.

# %% [markdown]
# Na potrzeby testu statystycznego i sformułowania poprawnej hipotezy podzieliłem obecną populację na dwie - kobiet i mężczyzn. Dodatkowo usunąłem dane, które nie będą przydatne w teście. Pozostawione zmienne określają płeć oraz diagnozę.

# %%
men = df[df.sex==0][["sex","target"]]
woman = df[df.sex==1][["sex","target"]]
men
# Out:
#       sex  target
# 4       0       0
# 5       0       1
# 10      0       1
# 11      0       0
# 12      0       1
# ...   ...     ...
# 996     0       0
# 1004    0       1
# 1005    0       0
# 1014    0       1
# 1023    0       1
#
# [312 rows x 2 columns]

# %% [markdown]
# # Hipoteza, wybór testu
#
# Hipoteza, którą chciałbym sprawdzić odnosi się do odsetka kobiet ze zdiagnozowaną chorobą sercą. Z mojej wiedzy wynika, że kobiety częściej zmagają się z tego typu chorobami, wskazuje też na to wstępna analiza eksploracyjna, chcę więc sprawdzić czy ich odsetek w populacji jest większy od 65%. W tym celu podzieliłem populacje na kobiety oraz mężczyzn, dlatego interesować będzie mnie różnica średnich. Hipotezy będą miały następującą postać:
#
# H0: pk-pm = 0.15 <br>
# H1: pk-pm > 0.15 <br>
#
# Jako że dane atrybutu target są binarne wykorzystam fakt, że tworzą rozkład dwumianowy - średnia wartość to jednocześnie prawdopodobieństwo sukcesu. Jako sukces mam na myśli wylosowanie z danej próby obserwacji, dla której wartość target wynosi 1. Dzięki temu możemy wyznaczyć estymowane odchylenie standardowe zgodnie ze wzorem na odchylenie standardowe dla średniej w rozkładzie Bernoulliego:
# $$DX = \sqrt{\frac{p(1-p)}{n}}$$
#
# Korzystać będę z testu Z dla dwóch niesparowanych populacji: $$ Z_{\bar{X_1}-\bar{X_2}} = \frac{(\bar{X_1} - \bar{X_2})-(\mu_1 - \mu_2)}{\sqrt{\frac{\sigma_1^2}{n_1} + \frac{\sigma_2^2}{n_2}}} $$
#
# Komentarze tu .
#
# [//]: # "Histogram przypisany do atrybutu płeć nie przypomina kształtem rozkładu normalnego lecz próba jest bardzo duża, więc sprawdzam warunki, które zezwolą na użycie Centralnego Twierdzenia Granicznego:"
#
# np = n(1-p0)
#
# Nie znam wariancji populacji, mimo tego zdecydowałem się na wybór testu Z jako przybliżenie testu T, ponieważ dla tak dużej liczby swobody (1024) rozkłady te będą bliźniaczo podobne.
#
#
# Wynik testu, sugeruje że można mieć 99% pewność, że kobiety ...
