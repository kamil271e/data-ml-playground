# %% [markdown]
# # FIFA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os 

pd.plotting.register_matplotlib_converters()
# %matplotlib inline
plt.style.use('ggplot')
if not os.path.exists('data/fifa.csv'):
    os.symlink('data/data-for-vis/fifa.csv','data/fifa.csv') # creates symbolic link, pointing to first argument
print("Setup")
# Out:
# Setup

# %% [markdown]
# `pd.plotting.register_matplotlib_converters()` <br>
# This function modifies the global matplotlib.units.registry dictionary. pandas adds custom converters for:
# - pd.Timestamp
# - pd.Period
# - np.datetime64
# - datetime.datetime
# - datetime.date
# - datetime.time
#
# `%matplotlib inline` <br>
# Provided you are running IPython, the %matplotlib inline will make your plot outputs appear and be stored within the notebook. "Magic function". Weird coz I've never used it before and it worked fine all the time.

# %%
fifa_path = "data/fifa.csv"
fifa_data = pd.read_csv(fifa_path, index_col="Date", parse_dates=True)
fifa_data
# Out:
#              ARG  BRA   ESP   FRA  GER   ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ...          ...  ...   ...   ...  ...   ...
# 2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 6 columns]

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=fifa_data)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # SPOTIFY

# %%
spotify_path = 'data/spotify.csv'
spotify_data = pd.read_csv(spotify_path, index_col='Date', parse_dates=True)
spotify_data
# sd.head() # sd.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN        NaN
# 2017-01-07      13190270        NaN                       NaN        NaN
# 2017-01-08      13099919        NaN                       NaN        NaN
# 2017-01-09      14506351        NaN                       NaN        NaN
# 2017-01-10      14275628        NaN                       NaN        NaN
# ...                  ...        ...                       ...        ...
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN
# ...                   ...
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0
#
# [366 rows x 5 columns]

# %%
plt.figure(figsize=(14,6))
plt.title("Daily global streams of popular songs in 2017-2018")
sns.lineplot(data=spotify_data)
# Out:
# <AxesSubplot:title={'center':'Daily global streams of popular songs in 2017-2018'}, xlabel='Date'>

# %%
#list(spotify_data.columns)
plt.figure(figsize=(14,6))
plt.title("2 song comparison")
sns.lineplot(data=spotify_data['HUMBLE.'], label="HUMBLE.")
sns.lineplot(data=spotify_data['Despacito'], label="Irrelevant trash song")
plt.xlabel("Date")
plt.ylabel("")
plt.show()

# %% [markdown]
# # MUSEUM

# %%
museum_path = 'data/museum_visitors.csv'
museum_data = pd.read_csv(museum_path, index_col='Date', parse_dates=True)
museum_data.tail()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2018-07-01        23136              4191                     2620
# 2018-08-01        20815              4866                     2409
# 2018-09-01        21020              4956                     2146
# 2018-10-01        19280              4622                     2364
# 2018-11-01        17163              4082                     2385
#
#             America Tropical Interpretive Center
# Date
# 2018-07-01                                  4718
# 2018-08-01                                  3891
# 2018-09-01                                  3180
# 2018-10-01                                  3775
# 2018-11-01                                  4562

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=museum_data)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ca_museum_jul18 = museum_data['Chinese American Museum'] #.value_counts()
# first date - 01.01.2014
# we want 01.07.2018
# month diff = 12*4 + 7 = 55
# index = 55-1=54
ca_museum_jul18[54]
# Out:
# 2620

# %%
ca_museum_jul18.index[0].date()
# Out:
# datetime.date(2014, 1, 1)

# %% [markdown]
# # FLIGHTS

# %%
flight_path = 'data/flight_delays.csv'
flight_data = pd.read_csv(flight_path, index_col='Month')
flight_data
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
#              HA         MQ         NK         OO         UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894   6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895   7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693   4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796   4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162   6.827695  0.681605
# 6      0.882786   9.639323  35.561501   8.338477  16.932663  5.766296
# 7      2.001586   3.980289  14.352382   6.790333  10.262551       NaN
# 8      7.448029   1.896565  20.519018   5.606689   5.014041       NaN
# 9      3.696915  -2.167268   8.000101   1.530896  -1.794265       NaN
# 10     0.467074  -3.735054   6.810736   1.750897  -2.456542       NaN
# 11    -2.719894   0.220061   7.543881   4.925548   0.281064       NaN
# 12    -1.706475   0.662486  12.733123  10.947612   7.012079       NaN
#
#               VX         WN
# Month
# 1       1.420702   3.389466
# 2       7.784410   3.501363
# 3       5.348207   3.263341
# 4       0.995507   2.996399
# 5       7.102021   5.680777
# 6       5.779415  10.743462
# 7       7.135773  10.504942
# 8       5.106221   5.532108
# 9       0.070998  -1.336260
# 10      2.254278  -0.688851
# 11      0.116370   0.995684
# 12     13.498720   6.720893

# %%
plt.figure(figsize=(10,6))
plt.title("Average Arrival Delay for Spirit Airlines Flights, by Month")
sns.barplot(x=flight_data.index, y=flight_data['NK'])
plt.ylabel("Arrival delay (in minutes)")
# Out:
# Text(0, 0.5, 'Arrival delay (in minutes)')

# %%
plt.figure(figsize=(14,7))
plt.title("Average Arrival Delay for Each Airline, by Month")
sns.heatmap(data=flight_data, annot=True)
plt.xlabel("Airline")
# Out:
# Text(0.5, 42.0, 'Airline')

# %% [markdown]
# # IGN_GAME
#
# `iloc` function has access to specified row of data frame.

# %%
ign_path = 'data/ign_scores.csv'
ign_data = pd.read_csv(ign_path, index_col='Platform')
ign_data
# Out:
#                         Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast             6.882857           7.511111   6.281818  8.200000
# Game Boy Advance      6.373077           7.507692   6.057143  6.226316
# Game Boy Color        6.272727           8.166667   5.307692  4.500000
# GameCube              6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS          6.670833           7.481818   7.414286  6.614286
# Nintendo 64           6.649057           8.250000   7.000000  5.681250
# Nintendo DS           5.903608           7.240000   6.259804  6.320000
# Nintendo DSi          6.827027           8.500000   6.090909  7.500000
# PC                    6.805791           7.334746   7.136798  7.166667
# PlayStation           6.016406           7.933333   6.313725  6.553731
# PlayStation 2         6.467361           7.250000   6.315152  7.306349
# PlayStation 3         6.853819           7.306154   6.820988  7.710938
# PlayStation 4         7.550000           7.835294   7.388571  7.280000
# PlayStation Portable  6.467797           7.000000   6.938095  6.822222
# PlayStation Vita      7.173077           6.133333   8.057143  7.527273
# Wii                   6.262718           7.294643   6.234043  6.733333
# Wireless              7.041699           7.312500   6.972414  6.740000
# Xbox                  6.819512           7.479032   6.821429  7.029630
# Xbox 360              6.719048           7.137838   6.857353  7.552239
# Xbox One              7.702857           7.566667   7.254545  7.171429
# iPhone                6.865445           7.764286   7.745833  6.087500
#
#                       Platformer    Puzzle       RPG    Racing   Shooter  \
# Platform
# Dreamcast               8.340000  8.088889  7.700000  7.042500  7.616667
# Game Boy Advance        6.970588  6.532143  7.542857  6.657143  6.444444
# Game Boy Color          6.352941  6.583333  7.285714  5.897436  4.500000
# GameCube                6.665714  6.133333  7.890909  6.852632  6.981818
# Nintendo 3DS            7.503448  8.000000  7.719231  6.900000  7.033333
# Nintendo 64             6.889655  7.461538  6.050000  6.939623  8.042857
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,12))
sns.barplot(data=ign_data_t, orient='h')
#sns.barplot(x=ign_data_t, y=ign_data_t.index)
# Out:
# <AxesSubplot:ylabel='Platform'>

# %%
worst = 1000000
best = -1
worst_genre = ''
best_genre = ''

for i in range(len(ign_data_t)):
    curr_score = sum(ign_data_t.iloc[i]) / len(ign_data_t.iloc[i])
    if curr_score < worst:
        worst = curr_score
        worst_genre = ign_data_t.index[i]
    if curr_score > best:
        best = curr_score
        best_genre = ign_data_t.index[i]

print('Best genre: {}, score: {}\nWorst genre: {}, score: {}'.format(best_genre,best,worst_genre, worst))
# Out:
# Best genre: RPG, score: 7.539588932655596
# Worst genre: Action, score: 6.707490495214333

# %%
worst = 1000000
best = -1
worst_platform = ''
best_platform = ''

for i in range(len(ign_data)):
    curr_score = sum(ign_data.iloc[i]) / len(ign_data.iloc[i])
    if curr_score < worst:
        worst = curr_score
        worst_platform = ign_data.index[i]
    if curr_score > best:
        best = curr_score
        best_platform = ign_data.index[i]

print('Best platform: {}, score: {}\nWorst platform: {}, score: {}'.format(best_platform,best,worst_platform, worst))
# Out:
# Best platform: Xbox One, score: 7.714107142857142
# Worst platform: Game Boy Color, score: 6.16310071787158

# %%
# Avg score for pc
indx = list(ign_data.index).index("PC")
score = sum(ign_data.iloc[indx]) / len(ign_data.iloc[indx])
print(score)

# Highest score for PC
score = max(ign_data.iloc[indx])
print(score)
# Out:
# 7.164532551920284
# 7.759930313588847

# %%
# Average for racing games
plt.figure(figsize=(8,6))
sns.barplot(x=ign_data['Racing'],y=ign_data.index)
plt.title("Average Score for Racing Games by Platform")
# Out:
# Text(0.5, 1.0, 'Average Score for Racing Games by Platform')

# %%
plt.figure(figsize=(8,8))
sns.heatmap(data=ign_data, annot=True, cmap='RdYlGn')
# Out:
# <AxesSubplot:ylabel='Platform'>

# %% [markdown]
# # INSURANCE

# %%
insurance_path = 'data/insurance.csv'
insurance_data = pd.read_csv(insurance_path)
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.lmplot(x='bmi', y='charges', hue='smoker', data=insurance_data)

# %%
sns.swarmplot(x=insurance_data['smoker'], y=insurance_data['charges'], s=2) 
# s-> changing size of markers
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %% [markdown]
# # CANDY

# %%
candy_path = 'data/candy.csv'
candy_data = pd.read_csv(candy_path, index_col='id')
candy_data
# Out:
#                 competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0                    100 Grand       Yes     No     Yes             No     No
# 1                 3 Musketeers       Yes     No      No             No    Yes
# 2                    Air Heads        No    Yes      No             No     No
# 3                   Almond Joy       Yes     No      No            Yes     No
# 4                    Baby Ruth       Yes     No     Yes            Yes    Yes
# ..                         ...       ...    ...     ...            ...    ...
# 78                   Twizzlers        No    Yes      No             No     No
# 79                    Warheads        No    Yes      No             No     No
# 80        Welch's Fruit Snacks        No    Yes      No             No     No
# 81  Werther's Original Caramel        No     No     Yes             No     No
# 82                    Whoppers       Yes     No      No             No     No
#
#    crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 0               Yes   No  Yes       No         0.732         0.860   66.971725
# 1                No   No  Yes       No         0.604         0.511   67.602936
# 2                No   No   No       No         0.906         0.511   52.341465
# 3                No   No  Yes       No         0.465         0.767   50.347546
# 4                No   No  Yes       No         0.604         0.767   56.914547
# ..              ...  ...  ...      ...           ...           ...         ...
# 78               No   No   No       No         0.220         0.116   45.466282
# 79               No  Yes   No       No         0.093         0.116   39.011898
# 80               No   No   No      Yes         0.313         0.313   44.375519
# 81               No  Yes   No       No         0.186         0.267   41.904308
# 82              Yes   No   No      Yes         0.872         0.848   49.524113
#
# [83 rows x 13 columns]

# %%
# The most sugar
m = max(candy_data['sugarpercent'])
i = list(candy_data['sugarpercent']).index(m)
print("The most sugar level: {}, competition name: {}".format(m, candy_data['competitorname'][i]))
# Out:
# The most sugar level: 0.98799998, competition name: Reese's stuffed with pieces

# %%
sns.scatterplot(x=candy_data['sugarpercent'],y=candy_data['winpercent'])
# Out:
# <AxesSubplot:xlabel='sugarpercent', ylabel='winpercent'>

# %%
sns.regplot(x=candy_data['sugarpercent'],y=candy_data['winpercent'])
# Out:
# <AxesSubplot:xlabel='sugarpercent', ylabel='winpercent'>

# %%
sns.scatterplot(x=candy_data['pricepercent'], y=candy_data['winpercent'], hue=candy_data['chocolate'])
# Out:
# <AxesSubplot:xlabel='pricepercent', ylabel='winpercent'>

# %%
sns.lmplot(x='pricepercent', y='winpercent', hue='chocolate', data=candy_data)

# %%
sns.swarmplot(x=candy_data['chocolate'],y=candy_data['winpercent'])
# better plot than the one above.
# Out:
# <AxesSubplot:xlabel='chocolate', ylabel='winpercent'>

# %% [markdown]
# # IRIS

# %%
iris_path = 'data/iris.csv'
iris_data = pd.read_csv(iris_path, index_col="Id")
iris_data
# Out:
#      Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                  5.1               3.5                1.4               0.2
# 2                  4.9               3.0                1.4               0.2
# 3                  4.7               3.2                1.3               0.2
# 4                  4.6               3.1                1.5               0.2
# 5                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 146                6.7               3.0                5.2               2.3
# 147                6.3               2.5                5.0               1.9
# 148                6.5               3.0                5.2               2.0
# 149                6.2               3.4                5.4               2.3
# 150                5.9               3.0                5.1               1.8
#
#             Species
# Id
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# ..              ...
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
# 150  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.histplot(iris_data['Petal Length (cm)'])
# Out:
# <AxesSubplot:xlabel='Petal Length (cm)', ylabel='Count'>

# %%
sns.kdeplot(data=iris_data['Petal Length (cm)'], shade=True)
# Out:
# <AxesSubplot:xlabel='Petal Length (cm)', ylabel='Density'>

# %%
sns.jointplot(x=iris_data['Petal Length (cm)'], y=iris_data['Sepal Width (cm)'], kind='kde')

# %%
sns.kdeplot(data=iris_data, x='Petal Length (cm)', hue="Species", shade=True)
plt.title("Distribution of Petal Lengths, by Species")
print(end="")

# %% [markdown]
# # CANCER

# %%
cancer_path = 'data/cancer.csv'
cancer_data = pd.read_csv(cancer_path, index_col='Id')
cancer_data
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
# ...            ...            ...             ...               ...
# 926125           M         20.920           25.09            143.00
# 926424           M         21.560           22.39            142.00
# 926682           M         20.130           28.25            131.20
# 926954           M         16.600           28.08            108.30
# 927241           M         20.600           29.33            140.10
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# 8510653         520.0            0.10750             0.12700
# 8510824         273.9            0.10240             0.06492
# 854941          523.8            0.08983             0.03766
# 85713702        201.9            0.08600             0.05943
# ...               ...                ...                 ...
# 926125         1347.0            0.10990             0.22360
# 926424         1479.0            0.11100             0.11590
# 926682         1261.0            0.09780             0.10340
# 926954          858.1            0.08455             0.10230
# 927241         1265.0            0.11780             0.27700
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  \
# Id
# 8510426            0.06664               0.047810           0.1885
# 8510653            0.04568               0.031100           0.1967
# 8510824            0.02956               0.020760           0.1815
# 854941             0.02562               0.029230           0.1467
# 85713702           0.01588               0.005917           0.1769
# ...                    ...                    ...              ...
# 926125             0.31740               0.147400           0.2149
# 926424             0.24390               0.138900           0.1726
# 926682             0.14400               0.097910           0.1752
# 926954             0.09251               0.053020           0.1590
# 927241             0.35140               0.152000           0.2397
#
#           Fractal dimension (mean)  Radius (se)  Texture (se)  Perimeter (se)  \
# Id
# 8510426                    0.05766       0.2699        0.7886           2.058
# 8510653                    0.06811       0.1852        0.7477           1.383
# 8510824                    0.06905       0.2773        0.9768           1.909
# 854941                     0.05863       0.1839        2.3420           1.170
# 85713702                   0.06503       0.1563        0.9567           1.094
# ...                            ...          ...           ...             ...
# 926125                     0.06879       0.9622        1.0260           8.758
# 926424                     0.05623       1.1760        1.2560           7.673
# 926682                     0.05533       0.7655        2.4630           5.203
# 926954                     0.05648       0.4564        1.0750           3.425
# 927241                     0.07016       0.7260        1.5950           5.772
#
#           Area (se)  Smoothness (se)  Compactness (se)  Concavity (se)  \
# Id
# 8510426      23.560         0.008462          0.014600         0.02387
# 8510653      14.670         0.004097          0.018980         0.01698
# 8510824      15.700         0.009606          0.014320         0.01985
# 854941       14.160         0.004352          0.004899         0.01343
# 85713702      8.205         0.008968          0.016460         0.01588
# ...             ...              ...               ...             ...
# 926125      118.800         0.006399          0.043100         0.07845
# 926424      158.700         0.010300          0.028910         0.05198
# 926682       99.040         0.005769          0.024230         0.03950
# 926954       48.550         0.005903          0.037310         0.04730
# 927241       86.220         0.006522          0.061580         0.07117
#
#           Concave points (se)  Symmetry (se)  Fractal dimension (se)  \
# Id
# 8510426              0.013150        0.01980                0.002300
# 8510653              0.006490        0.01678                0.002425
# 8510824              0.014210        0.02027                0.002968
# 854941               0.011640        0.02671                0.001777
# 85713702             0.005917        0.02574                0.002582
# ...                       ...            ...                     ...
# 926125               0.026240        0.02057                0.006213
# 926424               0.024540        0.01114                0.004239
# 926682               0.016780        0.01898                0.002498
# 926954               0.015570        0.01318                0.003892
# 927241               0.016640        0.02324                0.006185
#
#           Radius (worst)  Texture (worst)  Perimeter (worst)  Area (worst)  \
# Id
# 8510426           15.110            19.26              99.70         711.2
# 8510653           14.500            20.49              96.09         630.5
# 8510824           10.230            15.66              65.13         314.9
# 854941            13.300            22.81              84.46         545.9
# 85713702           8.964            21.96              57.26         242.2
# ...                  ...              ...                ...           ...
# 926125            24.290            29.41             179.10        1819.0
# 926424            25.450            26.40             166.10        2027.0
# 926682            23.690            38.25             155.00        1731.0
# 926954            18.980            34.12             126.70        1124.0
# 927241            25.740            39.42             184.60        1821.0
#
#           Smoothness (worst)  Compactness (worst)  Concavity (worst)  \
# Id
# 8510426              0.14400              0.17730            0.23900
# 8510653              0.13120              0.27760            0.18900
# 8510824              0.13240              0.11480            0.08867
# 854941               0.09701              0.04619            0.04833
# 85713702             0.12970              0.13570            0.06880
# ...                      ...                  ...                ...
# 926125               0.14070              0.41860            0.65990
# 926424               0.14100              0.21130            0.41070
# 926682               0.11660              0.19220            0.32150
# 926954               0.11390              0.30940            0.34030
# 927241               0.16500              0.86810            0.93870
#
#           Concave points (worst)  Symmetry (worst)  Fractal dimension (worst)
# Id
# 8510426                  0.12880            0.2977                    0.07259
# 8510653                  0.07283            0.3184                    0.08183
# 8510824                  0.06227            0.2450                    0.07773
# 854941                   0.05013            0.1987                    0.06169
# 85713702                 0.02564            0.3105                    0.07409
# ...                          ...               ...                        ...
# 926125                   0.25420            0.2929                    0.09873
# 926424                   0.22160            0.2060                    0.07115
# 926682                   0.16280            0.2572                    0.06637
# 926954                   0.14180            0.2218                    0.07820
# 927241                   0.26500            0.4087                    0.12400
#
# [569 rows x 31 columns]

# %%
#from pandas_profiling import ProfileReport
#profile = ProfileReport(cancer_data)
#profile

# %%
# largest value for Perimeter (mean)
m = max(cancer_data['Perimeter (mean)'])
i = list(cancer_data['Perimeter (mean)']).index(m)
print("Largest perimeter (mean): {}, Id: {}".format(m,cancer_data.index[i]))
# Out:
# Largest perimeter (mean): 188.5, Id: 8810703

# %%
#sns.histplot(cancer_data['Area (mean)'], hue=cancer_data['Diagnosis'])
cancer_m = cancer_data[cancer_data.Diagnosis == 'M']
cancer_b = cancer_data[cancer_data.Diagnosis == "B"]

sns.histplot(cancer_b['Area (mean)'], label='Benign', color='g')
sns.histplot(cancer_m['Area (mean)'], label='Malicious', color='r')

plt.legend()

# %%
sns.kdeplot(data=cancer_b['Radius (worst)'], shade=True, label='Benign', color='g')
sns.kdeplot(data=cancer_m['Radius (worst)'], shade=True, label='Malicious', color='r')
plt.legend()

# %% [markdown]
# ![plots.png](attachment:plots.png)

# %% [markdown]
# ### Seaborn styles:
# - `darkgrid`
# - `whitegrid`
# - `dark`
# - `white`
# - `ticks`
# <br> <br> To change style: `sns.set_style('stylename')`
